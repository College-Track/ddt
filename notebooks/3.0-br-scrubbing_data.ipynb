# %%
import pandas as pd
import os
from pathlib import Path
import uuid
import names
# clean demographic data

raw_data = Path("..") / "data" / "raw"






df = pd.read_csv(raw_data.joinpath("student_count_demo.csv"))


# df.loc['18 Digit ID'] = df['18 Digit ID'].apply(lambda x: uuid.uuid1())

# print

# %%
# Replacing names with random names
df['Full Name'] = df['Full Name'].apply(lambda x: names.get_full_name())

# %%
import random
from datetime import datetime


def genDateOfBirth(number=1):
    CurrentTime = datetime.now()
    Year = random.randrange(2000, CurrentTime.year)
    for item in range(number):
        yield random.randrange(2000,CurrentTime.year), random.randrange(1, 12), random.randrange(1, 31)

dateTimeThatIwant = genDateOfBirth()

# %%
df['Birthdate'] = df['Birthdate'].apply(lambda x: next(f'{month}/{day}/{year}' for year, month, day in genDateOfBirth()))

# %%
for year, month, day in genDateOfBirth():
    print(year)
# Out:
# 2006

# %%
df.Birthdate.value_counts()
# Out:
# [4/9/2018]      4
# [6/12/2007]     4
# [3/24/2006]     4
# [7/15/2013]     4
# [10/20/2006]    4
#                ..
# [5/13/2003]     1
# [7/6/2008]      1
# [8/20/2004]     1
# [1/18/2002]     1
# [10/14/2000]    1
# Name: Birthdate, Length: 2405, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0         18 Digit ID       Full Name  High School Class  \
# 0           0  0034600001TQpY2AAL    Ronald Davis               2017
# 1           1  0034600001TQqnGAAT   Elton Coleman               2018
# 2           2  0034600001TQphxAAD   Sheri Tullius               2015
# 3           3  0034600001TQpriAAD    Flora Faught               2015
# 4           4  0034600001TQqvyAAD  Eldon Williams               2015
#
#                                      Region                   Site  \
# 0  College Track Northern California Region  College Track Oakland
# 1  College Track Northern California Region  College Track Oakland
# 2  College Track Northern California Region  College Track Oakland
# 3  College Track Northern California Region  College Track Oakland
# 4  College Track Northern California Region  College Track Oakland
#
#      Birthdate Age  Qualifies for FRL?  Indicator: Low-Income  \
# 0   [1/9/2003]  20                True                   True
# ...

# %%
df['Birthdate'].name = "Birthdate (MOD)"

# %%
df['Full Name'].name = "Full Name (MOD)"

# %%
df = df.drop(columns=['test'])

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df['18 Digit ID'] = df['18 Digit ID'].apply(lambda x: str(uuid.uuid1()))

# %%
df.head()
# Out:
#                             18 Digit ID       Full Name  High School Class  \
# 0  ff1cc330-10a8-11ea-9452-4c327597d7ef    Ronald Davis               2017
# 1  ff1cc4a2-10a8-11ea-9452-4c327597d7ef   Elton Coleman               2018
# 2  ff1cc52e-10a8-11ea-9452-4c327597d7ef   Sheri Tullius               2015
# 3  ff1cc592-10a8-11ea-9452-4c327597d7ef    Flora Faught               2015
# 4  ff1cc5f6-10a8-11ea-9452-4c327597d7ef  Eldon Williams               2015
#
#                                      Region                   Site  Birthdate  \
# 0  College Track Northern California Region  College Track Oakland  6/24/2010
# 1  College Track Northern California Region  College Track Oakland   4/4/2003
# 2  College Track Northern California Region  College Track Oakland  5/15/2007
# 3  College Track Northern California Region  College Track Oakland  7/28/2014
# 4  College Track Northern California Region  College Track Oakland  5/29/2007
#
# ...

# %%
df.to_csv('test_demo.csv')
